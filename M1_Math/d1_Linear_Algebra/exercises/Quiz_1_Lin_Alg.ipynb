# %% [markdown]
# ## Linear Algebra Quiz #1
#
# ![title](./img/1_0.jpeg)
#
# We strongly suggest working with numpy :)

# %%
#Do your imports here
import numpy as np

# %% [markdown]
# ![title](./img/1_1.png)

# %%
# type a function that given a 3_dimensional vector it is able to calculate its magnitude

def magnitude_3(a,b,c):
    return np.sqrt((a**2) + (b**2) + (c**2))

print(magnitude_3(2, 3, 4))

# type a function that given a n_dimensional vector it is able to calculate its magnitude
# if you want to try this from python (not jupyter notebook) https://docs.python.org/3/library/argparse.html would be a good addition
# if you are doing this from a jupyter notebook only, you can try to promt the user for an input  

def magnitude_complete(vector):
    sum = 0
    return np.sqrt(np.dot(vector))
    # for i in range(len(vector)):
    #     sum += vector[i]**2
    # return np.sqrt(sum)

print(magnitude_complete([2, 3, 4]))
# Out:
# 5.385164807134504
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-c68178e15bdf> in <module>
#      17     # return np.sqrt(sum)
#      18
# ---> 19 print(magnitude_complete([2, 3, 4]))
#
# <ipython-input-34-c68178e15bdf> in magnitude_complete(vector)
#      12 def magnitude_complete(vector):
#      13     sum = 0
# ---> 14     return np.sqrt(np.dot(vector))
#      15     # for i in range(len(vector)):
#      16     #     sum += vector[i]**2
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# TypeError: dot() missing 1 required positional argument: 'b'

# %% [markdown]
# uncomment the following line when you are ready to test

# %%
magnitude_complete(1) == 1.0
#magnitude_complete(1,2) >= 2.236
#magnitude_complete(1,2,3) >= 3.741
#magnitude_complete(1,2,3,4,5) >= 5.477
#magnitude_complete(1,2,3,4,5) >= 7.416
# Out:
# True

# %% [markdown]
# ![title](./img/1_2.png)

# %%
def magnitude_vectors(a, b):
    #checks that size is equal
    
    #returns the magnitude

# %% [markdown]
# ![title](./img/1_3.png)

# %%
def direction_vectors(a, b):
    #checks that size is equal
    
    #returns the magnitude
    
# or if you want to do it all in one batch:
def magdir_vectors(a, b):
    #checks that size is equal
    
    #returns the magnitude and direction in a nicely printed format 
    #"The magnitude of a + b is X and the direction is Y"

# %% [markdown]
# ![title](./img/1_4.png)
# - What is the magnitude of αx⃗?
# - If α>0, will the direction of the resulting vector change?
# - If α<0, will the direction of the resulting vector change?
# - If −1<α<1, will ∥αx⃗∥  increase, decrease or stay the same?

# %%
def alpha_magnitude(alpha, b):
    
    #returns the resulting magnitude, if the direction has changed and what has happened to the vector
